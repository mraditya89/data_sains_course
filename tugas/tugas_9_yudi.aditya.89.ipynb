# %% [markdown]
# <b>Note</b>: Pada kuis kali ini kita akan menggunakan data diamonds.csv yang bisa kalian download [disini](https://drive.google.com/uc?export=download&id=1qQiM9utQUThTPq8jk8stPMh_y2zfqYOd). setelah di download, kalian pindahkan data tersebut satu level dengan direktori file notebook ini.

# %%
import pandas as pd
df = pd.read_csv('diamonds.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)

# define rounded function
def round6(num): return round(num,6)

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# Columns Metadata:
#
# carat: berat diamond
#
# cut: kualitas diamond
#
# color: warna diamond
#
# clarity: level kemurnian diamonds
#
# depth: tinggi dari diamond tabel
#
# table: lebar  dari diamond tabel
#
# price: harga diamond ($US)
#
# x: panjang
#
# y: lebar
#
# z: kedalaaman

# %% [markdown]
# <h2>Soal 1: Process Grouping</h2>
#
# Jelaskan prosess yang terjadi dalam grouping data menggungkan method <b>groupby()</b> dari pandas.

# %% [markdown]
# jawab:
# Grouping adalah suatu teknik memisahkan data berdasarkan kriteria tertentu. untuk melakukan grouping di pandas kita menggunakan suatu method yang bernama groupby().
# Proses ini dilakukan dalam 3 tahap yaitu split-apply-combine. penjelasan singkatnya sebagai berikut.
# - Splitting : Proses memisahkan data ke dalam suatu k group berdasarkan kriteria tertentu (argumen yang dikirim pada metode groupby).
# - Applying : Melakukan suatu operasi terhadap sekumpulan data di group-group tersebut.
# - Combining : Menggabungkan data menjadi suatu struktur baru

# %% [markdown]
# <h2>Soal 2: Grouping All Column</h2>
#
# Group data diamond berdasarkan cut (kualitas), lakukan aggregasi dengan fungsi rata2.
#
# Kemudian jawab pertanyaan berikut.
# - Berapa harga rata2 dari diamond berkualitas Premium

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1GKanuLzNv_pYBFVRBmQywxQw39uQBvSl)

# %%
# code here
gb = df.groupby("cut").agg("mean")
display(gb)
maxPrice = round6(gb["price"]["Premium"])
print("\nJawab:")
print(f"Harga rata2 dari diamond berkualitas Premium adalah {maxPrice}")
# Out:
#               carat      depth      table  ...         x         y         z
# cut                                        ...
# Fair       1.046137  64.041677  59.053789  ...  6.246894  6.182652  3.982770
# Good       0.849185  62.365879  58.694639  ...  5.838785  5.850744  3.639507
# Ideal      0.702837  61.709401  55.951668  ...  5.507451  5.520080  3.401448
# Premium    0.891955  61.264673  58.746095  ...  5.973887  5.944879  3.647124
# Very Good  0.806381  61.818275  57.956150  ...  5.740696  5.770026  3.559801
#
# [5 rows x 7 columns]
# Jawab:
# Harga rata2 dari diamond berkualitas Premium adalah 4584.257704

# %% [markdown]
# <h2>Soal 3: Grouping Some Column base on Multiple Criteria</h2>
#
# Lakukan groupby pada data berdasarkan kriteria cut (kualitas) dan color (warna) secara berurutan, dengan aggregasi pada column carat, table, dan price saja. dengan fungsi agregasi rata-rata.
#
# Kemudian jawab pertanyaan berikut:
# - Berapa harga diamond yang berkriteria premium dan berwarna J
# - Berapa nilai dari carat diamond yang berkriteria very good dan berwarna H

# %% [markdown]
# Expected Output:
#
# Note: gambar hanya sebagaian dari keseluruhan data
#
# ![alt text](https://drive.google.com/uc?id=1XB_uHor7ZCPQUH9uQjSfd6aC6_yJnjh9)

# %%
# code here
gb = df.groupby(["cut", "color"])[["carat", "table", "price"]].agg("mean")
gb
# Out:
#                     carat      table        price
# cut       color
# Fair      D      0.920123  58.969325  4291.061350
#           E      0.856607  59.364732  3682.312500
#           F      0.904712  59.453205  3827.003205
#           G      1.023822  58.773248  4239.254777
#           H      1.219175  58.696370  5135.683168
#           I      1.198057  59.237143  4685.445714
#           J      1.341176  58.917647  4975.655462
# Good      D      0.744517  58.541541  3405.382175
#           E      0.745134  58.779957  3423.644159
#           F      0.775930  58.910891  3495.750275
#           G      0.850896  58.471986  4123.482204
#           H      0.914729  58.611111  4276.254986
#           I      1.057222  58.773946  5078.532567
#           J      1.099544  58.813029  4574.172638
# Ideal     D      0.565766  55.965632  2629.094566
#           E      0.578401  55.967461  2597.550090
#           F      0.655829  55.924203  3374.939362
#           G      0.700715  55.902375  3720.706388
#           H      0.799525  55.965843  3889.334831
#           I      0.913029  56.021357  4451.970377
#           J      1.063594  56.012612  4918.186384
# Premium   D      0.721547  58.718964  3631.292576
#           E      0.717745  58.779461  3538.914420
#           F      0.827036  58.679279  4324.890176
#           G      0.841488  58.702360  4500.742134
#           H      1.016449  58.792034  5216.706780
#           I      1.144937  58.771849  5946.180672
#           J      1.293094  58.874752  6294.591584
# Very Good D      0.696424  58.041309  3470.467284
#           E      0.676317  58.038875  3214.652083
#           F      0.740961  57.848429  3778.820240
#           G      0.766799  57.784428  3872.753806
#           H      0.915948  57.903015  4535.390351
#           I      1.046952  58.105150  5255.879568
#           J      1.133215  58.277729  5103.513274

# %%
premJPrice = round6(gb["price"][("Premium", "J")])
vGoodHCarat = round6(gb["carat"][("Very Good", "H")])
print("Jawab:")
print(f"- Harga diamond yang berkriteria premium dan berwarna J adalah {premJPrice}")
print(f"- Nilai dari carat diamond yang berkriteria very good dan berwarna H adalah {vGoodHCarat}")
# Out:
# Jawab:
# - Harga diamond yang berkriteria premium dan berwarna J adalah 6294.591584
# - Nilai dari carat diamond yang berkriteria very good dan berwarna H adalah 0.915948

# %% [markdown]
# <h2>Soal 4: Group By Multiple Aggregate Base on Multiple Criteria</h2>
#
# Lakukan groupby pada data berdasarkan kriteria cut(kualitas) dan color (warna) secara berurutan kemudian aggregasi objek group by nya dengan fungsi rata2 dan median.
#
# Kemudian Jawab Pertanyaan berikut:
#
# - Berapa nilai median dari harga diamond berkualitas good dan berwarna F

# %% [markdown]
# Expected Output:
#
# Note : gambar hanya sebagaian dari keseluruhan data
#
# ![alt text](https://drive.google.com/uc?id=1fUPIse5ELrzj26ZyWBqsAVOUb6yf7UoD)

# %%
# code here
gb = df.groupby(["cut", "color"]).agg(["mean", "median"])
gb
# Out:
#                     carat             depth  ...      y         z
#                      mean median       mean  ... median      mean median
# cut       color                              ...
# Fair      D      0.920123  0.900  64.048466  ...  6.010  3.839877  3.900
#           E      0.856607  0.900  63.319643  ...  6.020  3.722143  3.760
#           F      0.904712  0.900  63.508013  ...  5.990  3.787821  3.815
#           G      1.023822  0.980  64.339809  ...  6.040  3.963153  3.970
#           H      1.219175  1.010  64.585149  ...  6.250  4.219373  4.090
#           I      1.198057  1.010  64.220571  ...  6.270  4.193486  4.080
#           J      1.341176  1.030  64.357143  ...  6.460  4.319664  4.150
# Good      D      0.744517  0.700  62.365710  ...  5.730  3.504864  3.540
#           E      0.745134  0.700  62.203751  ...  5.710  3.496066  3.480
#           F      0.775930  0.710  62.202310  ...  5.790  3.544609  3.580
#           G      0.850896  0.900  62.526636  ...  6.070  3.647922  3.790
#           H      0.914729  0.900  62.499573  ...  6.130  3.726937  3.830
#           I      1.057222  1.000  62.475096  ...  6.260  3.901513  3.895
#           J      1.099544  1.020  62.395765  ...  6.460  3.977459  4.010
# Ideal     D      0.565766  0.500  61.678370  ...  5.110  3.201800  3.160
#           E      0.578401  0.500  61.686677  ...  5.110  3.220346  3.150
#           F      0.655829  0.530  61.675562  ...  5.240  3.338732  3.220
#           G      0.700715  0.540  61.700164  ...  5.260  3.403120  3.230
#           H      0.799525  0.700  61.733194  ...  5.710  3.539917  3.510
#           I      0.913029  0.740  61.793598  ...  5.860  3.695270  3.600
#           J      1.063594  1.030  61.821987  ...  6.510  3.912757  4.010
# Premium   D      0.721547  0.580  61.169245  ...  5.340  3.415926  3.300
#           E      0.717745  0.580  61.175909  ...  5.360  3.408875  3.290
#           F      0.827036  0.760  61.259974  ...  5.860  3.588391  3.590
#           G      0.841488  0.755  61.279480  ...  5.870  3.579641  3.610
#           H      1.016449  1.010  61.322034  ...  6.450  3.811699  3.960
#           I      1.144937  1.140  61.328641  ...  6.690  3.963894  4.130
#           J      1.293094  1.250  61.390099  ...  6.900  4.168020  4.260
# Very Good D      0.696424  0.610  61.750165  ...  5.490  3.405089  3.360
#           E      0.676317  0.570  61.730250  ...  5.365  3.373996  3.280
#           F      0.740961  0.700  61.721627  ...  5.720  3.472902  3.530
#           G      0.766799  0.700  61.841279  ...  5.710  3.509883  3.540
#           H      0.915948  0.900  61.968366  ...  6.160  3.713849  3.830
#           I      1.046952  1.005  61.934551  ...  6.360  3.890972  3.935
#           J      1.133215  1.060  61.902065  ...  6.575  4.006873  4.060
#
# [35 rows x 14 columns]

# %%
goodFMedPrice = round6(gb[('price', 'median')][('Good', 'F')])
print("Jawab")
print(f"Nilai median dari harga diamond berkualitas good dan berwarna F {goodFMedPrice}")
# Out:
# Jawab
# Nilai median dari harga diamond berkualitas good dan berwarna F 2647.0

# %% [markdown]
# jawab:

# %% [markdown]
# <h2>Soal 5: Group By With Different Aggregation for specific Column</h2>
#
# Lakukan groupby pada data berdasarkan criteria cut(kualitas), kemudian aggreagate dengan fungsi max pada column price dan fungsi min pada column carat.
#
# Kemudian Jawab Pertanyaan berikut:
#
# - Berapa nilai max dari price untuk diamond berkualitas Ideal

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1B_z5PBkLe4hNJJJV3JgDGP9G--llytKf)

# %%
# code here
gb = df.groupby("cut")[["price", "carat"]].agg({
    "price": "max", 
    "carat" : "min"
})
gb
# Out:
#            price  carat
# cut
# Fair       18574   0.22
# Good       18788   0.23
# Ideal      18806   0.20
# Premium    18823   0.20
# Very Good  18818   0.20

# %%
idealMaxPrice = gb["price"]["Ideal"]
print("Jawab:")
print(f"Nilai max dari price untuk diamond berkualitas Ideal {idealMaxPrice}")
# Out:
# Jawab:
# Nilai max dari price untuk diamond berkualitas Ideal 18806

# %% [markdown]
# <h2>Soal 6: Group By With Custom Function</h2>
#
# Lakukan groupby pada data berdasarkan criteria cut(kualitas), kemudian lakukan aggregasi dengan fungsi standar deviasi pada column carat dan fungsi rentang nilai antara max dan min pada column price.
#
# Kemudian jawab pertanyaan berikut:
# - Berapa selisih harga tertinggi dan terendah dari diamond berkualitas Premium

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1bl6_8KryXCxLfzpAf4YF80Qvt15a3uQ6)

# %%
# code here
gb = df.groupby("cut")[["price", "carat"]].agg({
    "price": lambda x: x.max()-x.min(), 
    "carat" : "std"
  })
gb
# Out:
#            price     carat
# cut
# Fair       18237  0.516404
# Good       18461  0.454054
# Ideal      18480  0.432876
# Premium    18497  0.515262
# Very Good  18482  0.459435

# %%
premDiffPrice = gb["price"]["Premium"] 
print("Jawab")
print(f"Selisih harga tertinggi dan terendah dari diamond berkualitas Premium adalah {premDiffPrice}")
# Out:
# Jawab
# Selisih harga tertinggi dan terendah dari diamond berkualitas Premium adalah 18497
