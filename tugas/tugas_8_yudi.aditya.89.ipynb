# %% [markdown]
# <h2>Soal 1: Pivoting and Melting</h2>
#
# Jelaskan itu pivoting dan melting data

# %% [markdown]
# Jawaban:
# - Pivoting adalah suatu metode pengubahan bentuk (reshaping) data dengan mengubah suatu data dengan memutar baris menjadi kolom.
# - Melting merupakan kebalikan dari pivoting dan biasa dikenal sebagai ‘unpivoting’. Dengan kata lain melting mengubah suatu data dengan memutar dari yang tadinya berada di posisi kolom menjadi di posisi baris.
# - Librari pandas memuat pengubahan bentuk dengan metode pivoting(pivot atau pivot_table) dan melting (melt)

# %% [markdown]
# <h2>Soal 2: Data structure Comprehension</h2>
#
# Data yang rapi adalah:
# 1. Setiap row menunjukan suatu unit observasi
# 2. Setiap column merupakan suatu unit variable
#
# Bagaimana pun, dalam menentukan unit observasi itu tergantung dari kasus yang di hadapi. sebagai seorang data scientist pasti akan menemukan berbagai bentuk struktur data. adalah sangat penting bagi seorang data scientist untuk dapat memahami dan menjelaskan setiap struktur data. Kemampuan memahami hubungan antara index baris, column dan isi data adalah kunci untuk memahami informasi apa yang data sedang beritahukan kepada kita.
#
# Di bawah ini terdapat 2 data yang berisi sama, tetapi memiliki struktur yang berbeda. Jelaskan perbedaan dari 2 struktur data tersebut

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1h13CDPzIjc-2XyRcyu-p1fet0Ep1gdMA)

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=12ji98ell5tNcCxeBzl4v8qqBtFMgDSr0)

# %% [markdown]
# Jawaban :
# - pada tabel pertama, "tipe ujian" berperan sebagai index dari tabel sedangkan "matpel" menjadi kolom. nilai (value) yang ditampilkan pada isi tabel adalah "rata2 waktu belajar".
#
# - pada tabel kedua data frame memiliki variabel identifier :"tipe ujian" dan variabel pengukuran :"matpel" dan kolom "rata2 waktu belajar" merupakan nilai pengukuran
#
# - Pada tabel pertama data dikelompokkan berdasarkan tipe waktu dan ujian, dengan begini pembaca bisa lebih cepat memahami data dibandingkan tabel yang kedua.
# - dengan pengelompokkan data seperti yang disajikan pada tabel pertama, kita bisa melakukan aggregasi data jika terdapat duplikasi data dengan nilai yang berbeda.
# - untuk mengubah table kedua menjadi bentuk tabel pertama kita bisa menggunakan metode pivot_table pada pandas.
# - Sebaliknya untuk mengubah tabel pertama ke tabel kedua bisa menggunakan metode melt
# - pada kasus ini data tersebut lebih baik ditampilkan seperti tabel pertama

# %% [markdown]
# <h2>Soal 3: Reshaping Data 1</h2>

# %%
import pandas as pd
import random

data = {
    'Tipe Ujian' : ['UTS1', 'UAS1', 'UTS2', 'UAS2']*3,
    'Mata Pelajaran' : ['Fisika']*4 + ['Matematika']*4+['Statistika']*4,
    'Rata2 Waktu Belajar (menit)' : [random.choice(range(200, 800)) for i in range(12)],
    'Rata2 Nilai Ujian' : [random.choice(range(40, 100)) for i in range(12)] 
}
df = pd.DataFrame(data)
df
# Out:
#    Tipe Ujian Mata Pelajaran  Rata2 Waktu Belajar (menit)  Rata2 Nilai Ujian
# 0        UTS1         Fisika                          312                 97
# 1        UAS1         Fisika                          495                 40
# 2        UTS2         Fisika                          474                 97
# 3        UAS2         Fisika                          636                 55
# 4        UTS1     Matematika                          339                 82
# 5        UAS1     Matematika                          560                 82
# 6        UTS2     Matematika                          414                 95
# 7        UAS2     Matematika                          397                 65
# 8        UTS1     Statistika                          403                 50
# 9        UAS1     Statistika                          356                 48
# 10       UTS2     Statistika                          220                 79
# 11       UAS2     Statistika                          355                 55

# %% [markdown]
# Perhatikan data di atas, kemudian ubahlah bentuknya agar sesuai yang di harapkan.

# %%
# code here
df.pivot_table(
    index="Tipe Ujian", 
    columns="Mata Pelajaran", 
    values=["Rata2 Nilai Ujian", "Rata2 Waktu Belajar (menit)"]
  )
# Out:
#                Rata2 Nilai Ujian             ... Rata2 Waktu Belajar (menit)
# Mata Pelajaran            Fisika Matematika  ...                  Matematika Statistika
# Tipe Ujian                                   ...
# UAS1                          40         82  ...                         560        356
# UAS2                          55         65  ...                         397        355
# UTS1                          97         82  ...                         339        403
# UTS2                          97         95  ...                         414        220
#
# [4 rows x 6 columns]

# %% [markdown]
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=1XufsfqZe7-XZLsb92SpATexy-QRZE0ow)

# %% [markdown]
# <h2>Soal 4: Reshaping Data 2</h2>

# %%
import pandas as pd

data = {
    'Hari' : ['Sabtu', 'Minggu'],
    'Kebun Binatang' : [271, 399],
    'Dufan' : [501, 700],
    'Disney' : [1000, 1001],
    'Bali' : [900, 803]
}
df = pd.DataFrame(data).set_index('Hari')
df
# Out:
#         Kebun Binatang  Dufan  Disney  Bali
# Hari
# Sabtu              271    501    1000   900
# Minggu             399    700    1001   803

# %% [markdown]
# diatas adalah data tentang jumlah pengunjung di berbagai tempat hiburan, ubahlah struktur data tersebut sehingga sesuai dengan hasil yang diharapkan.

# %%
pd.melt(
    df.reset_index(),
    id_vars = "Hari",
    var_name="Tempat Hiburan", 
    value_name="Pengunjung"
)
# Out:
#      Hari  Tempat Hiburan  Pengunjung
# 0   Sabtu  Kebun Binatang         271
# 1  Minggu  Kebun Binatang         399
# 2   Sabtu           Dufan         501
# 3  Minggu           Dufan         700
# 4   Sabtu          Disney        1000
# 5  Minggu          Disney        1001
# 6   Sabtu            Bali         900
# 7  Minggu            Bali         803

# %% [markdown]
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=159mIqcyfeD30EEcyZmmkovORa6cZDLtn)

# %% [markdown]
# <h2>Soal 5: Pivoting and Aggregating</h2>

# %%
import pandas as pd

data = {
    'Tipe Ujian' : ['UTS1', 'UAS1']*3,
    'Mata Pelajaran' :['Statistika', 'Fisika', 'Fisika', 'Statistika', 'Fisika', 'Statistika'],
    'Jumlah Peserta' : [14, 17, 12, 16, 14, 13]
}
df = pd.DataFrame(data).set_index('Tipe Ujian')
df
# Out:
#            Mata Pelajaran  Jumlah Peserta
# Tipe Ujian
# UTS1           Statistika              14
# UAS1               Fisika              17
# UTS1               Fisika              12
# UAS1           Statistika              16
# UTS1               Fisika              14
# UAS1           Statistika              13

# %% [markdown]
# Perhatikan bahwa data jumlah peserta ujian untuk suatu tipe ujian dan mata pelajaran tertentu ada yang duplikat, ubahlah struktur data tersebut dan lakukan aggregasi berjenis jumlah sehingga sesuai dengan hasil yang di harapkan
#
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=1emoz7orYR-0mCHffvAgM8j-V1P6yVHf0)

# %%
#Code here
pd.pivot_table(
    df.reset_index(), 
    index="Tipe Ujian", 
    columns="Mata Pelajaran", 
    values="Jumlah Peserta", 
    aggfunc="sum"
)
# Out:
# Mata Pelajaran  Fisika  Statistika
# Tipe Ujian
# UAS1                17          29
# UTS1                26          14
